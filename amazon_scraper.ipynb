# %%
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys

# %%
products=['laptops', 'Phones', 'Headphones', 'smart watches', 'Cameras', 'Printers', 'monitors', 'Home theater', 'router']

# %%
driver=webdriver.Chrome(r'Chromedriver.exe')
driver.get('https://www.amazon.in/')
amazon_urls=[]
for product in products:
    driver.find_element_by_xpath('//input[@id="twotabsearchtextbox"]').send_keys(product)
    driver.find_element_by_xpath('//input[@id="nav-search-submit-button"]').click()
    j=0
    urls=[]
    url_tags=[]
    while j<11:
        time.sleep(2)
        url_tags=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')
        for tag in url_tags:
            urls.append(tag.get_attribute('href'))
        driver.find_element_by_xpath('//li[@class="a-last"]').click()
        j+=1
    amazon_urls.append(urls)
    driver.find_element_by_xpath('//input[@id="twotabsearchtextbox"]').clear()

# %%
len(amazon_urls)
# Out:
# 9

# %%
len(amazon_urls[0]+amazon_urls[1]+amazon_urls[2]+amazon_urls[3]+amazon_urls[4]+amazon_urls[5]+amazon_urls[6]+amazon_urls[7]+amazon_urls[8])
# Out:
# 2001

# %%
urls=[]
for i in range(0,9):
    for url in amazon_urls[i]:
        urls.append(url)

# %%
len(urls)
# Out:
# 2001

# %% [raw]
# star=[]
# reviews=[]
#     for url in amazon_urls[i]:
#         driver.get(url)
#         try:
#             star_tags=driver.find_elements_by_xpath('//i[@data-hook="review-star-rating"]')
#             for tag in star_tags:
#                 star.append(tag.get_attribute('textContent'))
#         except:
#             star.append('-')
#         try:
#             review_tags=driver.find_elements_by_xpath('//div[@data-hook="review-collapsed"]/span')
#             for tag in review_tags:
#                 reviews.append(tag.get_attribute('textContent'))
#         except:
#             reviews.append('-')

# %%
star=[]
reviews=[]
for url in urls:
    driver.get(url)
    #time.sleep(2)
    try:
        star_tags=driver.find_elements_by_xpath('//div[@id="cm-cr-dp-review-list"]/div/div/div/div[2]/a/i/span')
        for tag in star_tags:
            star.append(tag.get_attribute('textContent'))
    except:
            star.append('-')
    try:
        review_tags=driver.find_elements_by_xpath('//div[@id="cm-cr-dp-review-list"]/div/div/div/div[4]')
        for tag in review_tags:
            reviews.append(tag.get_attribute('textContent'))
    except:
            reviews.append('-')

# %% [raw]
# df1=pd.DataFrame({})
# df1['stars']=star

# %% [raw]
# df2=pd.DataFrame({})
# df2['reviews']=reviews

# %% [raw]
# df1.to_csv('amazon_stars.csv')
# df2.to_csv('amazon_reviews.csv')

# %%
len(star)
# Out:
# 10575

# %%
len(reviews)
# Out:
# 10575

# %%
reviews
# Out:
# ['\n\n\n\n\n\n\n\n\n  \n  Your browser does not support HTML5 video.\n\n\n\n\n\n\n\n\n\n\n  \n  \n    \n  \xa0The package i has received was well protected and no damage occured. After I uncovering the package and started the laptop, it was so slow compared to my old vaio (sony i7). I was disappointed when it started to process slowly. But after signing and using it, there was no problem and it was running smoothly till now. (No backlighting, no bag, no headphones and mouse) only a laptop, a charger and a manual paper.\n\n  \nRead more',
#  '\n\n\n\n\n\n\n\n\n\n  \n  \n    \n  Laptop getting hang very much and very much slow start.This is happening within 2 days of purchase\n\n  \nRead more',
#  '\n\n\n\n\n\n\n\n\n\n  \n  \n    \n  It looks the screen size is small . Its not look 15.6 inch. Can some one help me\n\n  \nRead more',
# ...

# %%
df_amazonReviews=pd.DataFrame({})

# %%
df_amazonReviews['star']=star
df_amazonReviews['reviews']=reviews

# %%
df_amazonReviews.to_csv('amazonReviews.csv')

# %%
len(flip_reviews)

# %%
df1=pd.DataFrame({})
df2=pd.DataFrame({})
df1['star']=flip_stars
df2['reviews']=flip_reviews
